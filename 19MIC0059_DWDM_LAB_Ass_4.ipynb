# %% [markdown]
# # 1. Support Vector Machine or SVM is one of the most popular Supervised Learning algorithms, which is used for Classification. Collect the data set consists of 50 observations about student details based on selective attributes to classify the student is 9 pointer or not using Support Vector Machine.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
itemset = pd.read_csv('D:/Users/Lucky/(CSI3010)Data Warehousing & Data Mining(FALL-2021)/LAB/cgpa_dataset.csv')
itemset
# Out:
#      GPA  Placed 9_pointer
# 0   9.65       1       Yes
# 1   8.87       1       Yes
# 2   8.00       0        No
# 3   8.67       1        No
# 4   8.21       0        No
# 5   9.34       1       Yes
# 6   8.20       0        No
# 7   7.90       1        No
# 8   8.00       0        No
# 9   8.60       0        No
# 10  8.40       1        No
# 11  9.00       1       Yes
# 12  9.10       1       Yes
# 13  8.00       0        No
# 14  8.20       1        No
# 15  8.30       1        No
# 16  8.70       1       Yes
# 17  8.00       0        No
# 18  8.80       1       Yes
# 19  8.50       0        No
# 20  7.90       1        No
# 21  8.40       0        No
# 22  9.50       1       Yes
# 23  9.40       1       Yes
# 24  9.50       1       Yes
# 25  9.60       1       Yes
# 26  8.80       0        No
# 27  7.50       0        No
# 28  7.20       0        No
# 29  7.30       0        No
# 30  8.10       0        No
# 31  8.30       0        No
# 32  9.40       1       Yes
# ...

# %%
print(itemset.iloc[3])
# Out:
# GPA          8.67
# Placed          1
# 9_pointer      No
# Name: 3, dtype: object

# %%
print(itemset.iloc[1:3])
# Out:
#     GPA  Placed 9_pointer
# 1  8.87       1       Yes
# 2  8.00       0        No

# %%
print(itemset.iloc[:,0:2])    #:,0:2 -> weight and size attributes
# Out:
#      GPA  Placed
# 0   9.65       1
# 1   8.87       1
# 2   8.00       0
# 3   8.67       1
# 4   8.21       0
# 5   9.34       1
# 6   8.20       0
# 7   7.90       1
# 8   8.00       0
# 9   8.60       0
# 10  8.40       1
# 11  9.00       1
# 12  9.10       1
# 13  8.00       0
# 14  8.20       1
# 15  8.30       1
# 16  8.70       1
# 17  8.00       0
# 18  8.80       1
# 19  8.50       0
# 20  7.90       1
# 21  8.40       0
# 22  9.50       1
# 23  9.40       1
# 24  9.50       1
# 25  9.60       1
# 26  8.80       0
# 27  7.50       0
# 28  7.20       0
# 29  7.30       0
# 30  8.10       0
# 31  8.30       0
# 32  9.40       1
# 33  9.60       1
# 34  9.80       1
# 35  9.20       0
# 36  8.40       0
# 37  7.80       0
# 38  7.50       1
# 39  7.70       1
# 40  8.00       0
# 41  8.20       1
# 42  8.50       1
# 43  9.10       0
# 44  9.40       1
# 45  9.10       1
# 46  9.30       1
# 47  9.70       1
# 48  8.85       1
# 49  8.40       0

# %%
training_items, test_items = train_test_split(itemset,test_size=0.2)
X_train = training_items.iloc[:,0:2].values
X_test = training_items.iloc[:,0:2].values
Y_train = training_items.iloc[:,2].values  
Y_test = training_items.iloc[:,2].values        #:,2 -> class attribute

# %%
print(X_test)
# Out:
# [[8.4  0.  ]
#  [8.   0.  ]
#  [8.1  0.  ]
#  [7.7  1.  ]
#  [8.4  0.  ]
#  [8.   0.  ]
#  [8.2  1.  ]
#  [9.4  1.  ]
#  [8.7  1.  ]
#  [9.65 1.  ]
#  [8.2  0.  ]
#  [9.34 1.  ]
#  [8.6  0.  ]
#  [7.5  1.  ]
#  [8.4  1.  ]
#  [9.1  1.  ]
#  [9.5  1.  ]
#  [8.3  1.  ]
#  [9.4  1.  ]
#  [9.1  1.  ]
#  [9.3  1.  ]
#  [7.5  0.  ]
#  [8.21 0.  ]
#  [8.3  0.  ]
#  [7.9  1.  ]
#  [8.8  0.  ]
#  [8.   0.  ]
#  [7.3  0.  ]
#  [8.8  1.  ]
#  [9.7  1.  ]
#  [9.2  0.  ]
#  [9.5  1.  ]
#  [9.6  1.  ]
#  [8.   0.  ]
#  [7.8  0.  ]
#  [8.5  0.  ]
#  [8.67 1.  ]
#  [8.87 1.  ]
#  [9.6  1.  ]
#  [8.85 1.  ]]

# %%
print(Y_test)
# Out:
# ['No' 'No' 'No' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No'
#  'No' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'No' 'No'
#  'No' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes']

# %%
c2 = SVC(kernel = 'linear')
c2.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
pred = c2.predict(X_test)
print(pred)
# Out:
# ['No' 'No' 'No' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No'
#  'No' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'No' 'No'
#  'No' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes']

# %%
c2.predict([[8.8,1]])
# Out:
# array(['Yes'], dtype=object)

# %%
c2.predict([[7.7,0]])
# Out:
# array(['No'], dtype=object)

# %% [markdown]
# # 2. Training and testing the set involves constructing a training set that most resembles the test set and then using it as the basis for training a model. Collect the data set consists of 50 entries about salary details of the person to classify he/she is eligible for loan or not. Implement the classification algorithms such as decision tree and svm using training and testing method and verify how effective they are for the same prediction values.

# %% [markdown]
# # Decision Tree

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dataset = pd.read_csv('D:/Users/Lucky/(CSI3010)Data Warehousing & Data Mining(FALL-2021)/LAB/salary.csv')
dataset
# Out:
#     Age  YearsExperience  Salary Eligible_for_Loan
# 0    25              1.0   35000                No
# 1    25              1.0   40000                No
# 2    25              1.0   35000                No
# 3    26              2.0   40000                No
# 4    26              2.0   35000                No
# 5    27              2.0   40000                No
# 6    27              3.0   35000                No
# 7    27              3.0   50000               Yes
# 8    27              3.0   35000                No
# 9    28              3.5   60000               Yes
# 10   28              3.5   35000                No
# 11   29              3.5   40000                No
# 12   29              3.5   60000               Yes
# 13   29              4.0   50000               Yes
# 14   29              4.0   50000               Yes
# 15   30              4.0   45000                No
# 16   30              4.0   50000               Yes
# ...

# %%
train = ['Age', 'YearsExperience', 'Salary']
x = dataset[train]
y = dataset['Eligible_for_Loan']
print(x)
print(y)
# Out:
#     Age  YearsExperience  Salary
# 0    25              1.0   35000
# 1    25              1.0   40000
# 2    25              1.0   35000
# 3    26              2.0   40000
# 4    26              2.0   35000
# 5    27              2.0   40000
# 6    27              3.0   35000
# 7    27              3.0   50000
# 8    27              3.0   35000
# 9    28              3.5   60000
# 10   28              3.5   35000
# 11   29              3.5   40000
# 12   29              3.5   60000
# 13   29              4.0   50000
# 14   29              4.0   50000
# 15   30              4.0   45000
# 16   30              4.0   50000
# 17   30              4.5   60000
# 18   31              4.5   45000
# 19   31              4.5   50000
# 20   31              4.5   60000
# 21   32              4.5   60000
# 22   32              5.0   70000
# 23   32              5.0   70000
# 24   32              5.0   70000
# 25   33              5.0   60000
# 26   34              5.0   80000
# ...

# %%
d = DecisionTreeClassifier()
d = d.fit(x,y)

# %%
z = d.predict([[25,3.5,60000]])
print(z)
# Out:
# ['Yes']

# %%
z = d.predict([[35,5.5,40000]])
print(z)
# Out:
# ['No']

# %%
c.predict([[24,6.5,40000]])
# Out:
# array(['No'], dtype=object)

# %%
c.predict([[39,2.5,50000]])
# Out:
# array(['Yes'], dtype=object)

# %%
tree.plot_tree(d)
# Out:
# [Text(167.4, 163.07999999999998, 'X[2] <= 47500.0\ngini = 0.487\nsamples = 50\nvalue = [21, 29]'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]')]

# %% [markdown]
# # SVM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
itemset = pd.read_csv('D:/Users/Lucky/(CSI3010)Data Warehousing & Data Mining(FALL-2021)/LAB/salary.csv')
itemset
# Out:
#     Age  YearsExperience  Salary Eligible_for_Loan
# 0    25              1.0   35000                No
# 1    25              1.0   40000                No
# 2    25              1.0   35000                No
# 3    26              2.0   40000                No
# 4    26              2.0   35000                No
# 5    27              2.0   40000                No
# 6    27              3.0   35000                No
# 7    27              3.0   50000               Yes
# 8    27              3.0   35000                No
# 9    28              3.5   60000               Yes
# 10   28              3.5   35000                No
# 11   29              3.5   40000                No
# 12   29              3.5   60000               Yes
# 13   29              4.0   50000               Yes
# 14   29              4.0   50000               Yes
# 15   30              4.0   45000                No
# 16   30              4.0   50000               Yes
# ...

# %%
print(itemset.iloc[3])
# Out:
# Age                     26
# YearsExperience        2.0
# Salary               40000
# Eligible_for_Loan       No
# Name: 3, dtype: object

# %%
print(itemset.iloc[1:3])
# Out:
#    Age  YearsExperience  Salary Eligible_for_Loan
# 1   25              1.0   40000                No
# 2   25              1.0   35000                No

# %%
print(itemset.iloc[:,0:3])    #:,0:2 -> weight and size attributes
# Out:
#     Age  YearsExperience  Salary
# 0    25              1.0   35000
# 1    25              1.0   40000
# 2    25              1.0   35000
# 3    26              2.0   40000
# 4    26              2.0   35000
# 5    27              2.0   40000
# 6    27              3.0   35000
# 7    27              3.0   50000
# 8    27              3.0   35000
# 9    28              3.5   60000
# 10   28              3.5   35000
# 11   29              3.5   40000
# 12   29              3.5   60000
# 13   29              4.0   50000
# 14   29              4.0   50000
# 15   30              4.0   45000
# 16   30              4.0   50000
# 17   30              4.5   60000
# 18   31              4.5   45000
# 19   31              4.5   50000
# 20   31              4.5   60000
# 21   32              4.5   60000
# 22   32              5.0   70000
# 23   32              5.0   70000
# 24   32              5.0   70000
# 25   33              5.0   60000
# 26   34              5.0   80000
# ...

# %%
training_items, test_items = train_test_split(itemset,test_size=0.2)
X_train = training_items.iloc[:,0:3].values
X_test = training_items.iloc[:,0:3].values
Y_train = training_items.iloc[:,3].values  
Y_test = training_items.iloc[:,3].values        #:,2 -> class attribute

# %%
print(X_test)
# Out:
# [[3.1e+01 4.5e+00 6.0e+04]
#  [3.2e+01 5.0e+00 7.0e+04]
#  [2.8e+01 3.5e+00 6.0e+04]
#  [2.6e+01 3.0e+00 4.5e+04]
#  [3.4e+01 5.0e+00 8.0e+04]
#  [2.9e+01 3.5e+00 4.0e+04]
#  [2.5e+01 3.0e+00 3.5e+04]
#  [3.2e+01 3.0e+00 4.0e+04]
#  [2.7e+01 3.0e+00 4.5e+04]
#  [3.3e+01 4.0e+00 4.5e+04]
#  [3.2e+01 4.5e+00 6.0e+04]
#  [2.7e+01 2.0e+00 4.0e+04]
#  [3.6e+01 7.0e+00 4.0e+04]
#  [3.5e+01 6.0e+00 9.0e+04]
#  [2.9e+01 4.0e+00 5.0e+04]
#  [3.4e+01 6.0e+00 8.0e+04]
#  [3.2e+01 5.0e+00 7.0e+04]
#  [3.3e+01 5.0e+00 6.0e+04]
#  [2.7e+01 3.0e+00 3.5e+04]
#  [2.9e+01 4.0e+00 5.0e+04]
#  [3.4e+01 5.0e+00 8.0e+04]
#  [3.1e+01 4.5e+00 5.0e+04]
#  [3.6e+01 7.0e+00 9.0e+04]
#  [3.5e+01 6.0e+00 7.0e+04]
#  [2.9e+01 3.5e+00 6.0e+04]
#  [3.3e+01 4.0e+00 5.0e+04]
#  [3.0e+01 4.5e+00 6.0e+04]
#  [2.7e+01 3.0e+00 4.5e+04]
#  [3.5e+01 6.0e+00 1.0e+05]
#  [2.6e+01 7.0e+00 9.0e+04]
#  [2.6e+01 2.0e+00 4.0e+04]
#  [3.0e+01 3.0e+00 3.5e+04]
#  [2.7e+01 3.0e+00 3.5e+04]
#  [2.5e+01 1.0e+00 3.5e+04]
# ...

# %%
print(Y_test)
# Out:
# ['Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No' 'No' 'No' 'No' 'Yes' 'No' 'No'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'No' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes'
#  'No' 'No']

# %%
c = SVC(kernel = 'linear')
c.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
pred = c.predict(X_test)
print(pred)
# Out:
# ['Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No' 'No' 'No' 'No' 'Yes' 'No' 'No'
#  'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes'
#  'Yes' 'Yes' 'No' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes'
#  'No' 'No']

# %%
c.predict([[25,3.5,60000]])
# Out:
# array(['Yes'], dtype=object)

# %%
c.predict([[35,5.5,40000]])
# Out:
# array(['No'], dtype=object)

# %%
c.predict([[24,6.5,40000]])
# Out:
# array(['No'], dtype=object)

# %%
c.predict([[39,2.5,50000]])
# Out:
# array(['Yes'], dtype=object)

# %% [markdown]
# # 3. Implement the Random forest Supervised Machine Learning Algorithm that is used widely in Classification. (Assume own dataset at least 30 entries)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('D:/Users/Lucky/(CSI3010)Data Warehousing & Data Mining(FALL-2021)/LAB/heart.csv')
df
# Out:
#     age  sex  cp   BP  cholestrol  heart_disease
# 0    63    1   3  145         233              0
# 1    37    1   2  130         250              1
# 2    41    0   1  130         204              1
# 3    56    1   1  120         236              1
# 4    57    0   0  120         354              1
# 5    57    1   0  140         192              0
# 6    56    0   1  140         294              0
# 7    44    1   1  120         263              1
# 8    52    1   2  172         199              1
# 9    57    1   2  150         168              1
# 10   54    1   0  140         239              1
# 11   48    0   2  130         275              0
# 12   49    1   1  130         266              1
# 13   64    1   3  110         211              0
# 14   58    0   3  150         283              1
# 15   50    0   2  120         219              0
# 16   58    0   2  120         340              1
# 17   66    0   3  150         226              0
# ...

# %%
# Putting feature variable to X
X = df.drop('heart_disease',axis=1)
# Putting response variable to y
y = df['heart_disease']

# %%
# now lets split the data into train and test
from sklearn.model_selection import train_test_split

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size=0.7, 
                                                    random_state=42)
X_train.shape, X_test.shape
# Out:
# ((21, 5), (9, 5))

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(random_state=42, 
                                       n_jobs=-1, max_depth=5,
                                       n_estimators=100, oob_score=True)

# %%
# %%time
classifier_rf.fit(X_train, y_train)
# Out:
# Wall time: 437 ms
# RandomForestClassifier(max_depth=5, n_jobs=-1, oob_score=True, random_state=42)

# %%
# checking the oob score
classifier_rf.oob_score_
# Out:
# 0.6190476190476191

# %%
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf': [5,10,20,50,100,200],
    'n_estimators': [10,25,30,50,100,200]
}

# %%
from sklearn.model_selection import GridSearchCV
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=rf,
                           param_grid=params,
                           cv = 4,
                           n_jobs=-1, verbose=1, scoring="accuracy")

# %%
# %%time
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 180 candidates, totalling 720 fits
# Wall time: 1min 6s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100, 200],
#                          'n_estimators': [10, 25, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_score_
# Out:
# 0.6666666666666667

# %%
rf_best = grid_search.best_estimator_
rf_best
# Out:
# RandomForestClassifier(max_depth=2, min_samples_leaf=5, n_estimators=25,
#                        n_jobs=-1, random_state=42)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(80,40))
plot_tree(rf_best.estimators_[5], feature_names = X.columns,class_names=
          ['Disease', "No Disease"],filled=True);

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(80,40))
plot_tree(rf_best.estimators_[7], feature_names = X.columns,class_names=
          ['Disease', "No Disease"],filled=True);

# %%
rf_best.feature_importances_
# Out:
# array([0.31864151, 0.        , 0.20773933, 0.28      , 0.19361916])

# %%
imp_df = pd.DataFrame({
    "Varname": X_train.columns,
    "Imp": rf_best.feature_importances_
})

# %%
imp_df.sort_values(by="Imp", ascending=False)
# Out:
#       Varname       Imp
# 0         age  0.318642
# 3          BP  0.280000
# 2          cp  0.207739
# 4  cholestrol  0.193619
# 1         sex  0.000000
